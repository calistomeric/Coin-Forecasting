# %% [markdown]
# <a href="https://colab.research.google.com/github/calistomeric/Coin-Forecasting/blob/main/Character_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This Code Identifies handwritten character

# %%
# 1. Uninstall existing versions
# !pip uninstall -y torch torchvision torchaudio

# 2. Reinstall using the official wheels
# !pip install torch torchvision torchaudio
# Out:
# Found existing installation: torch 2.10.0
# Uninstalling torch-2.10.0:
#   Successfully uninstalled torch-2.10.0
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# ...
#   Using cached torch-2.10.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# ...
# Using cached torch-2.10.0-cp312-cp312-manylinux_2_28_x86_64.whl (915.7 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 93.7 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.8.6 requires torch<2.10,>=1.10, but you have torch 2.10.0 which is incompatible.
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-684570353.py in <cell line: 0>()
#       2 import torch.nn as nn
#       3 import torch.optim as optim
# ----> 4 import torchvision
#       5 from torchvision import transforms
#       6 from torch.utils.data import DataLoader
#
# ModuleNotFoundError: No module named 'torchvision'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.13070), (0.3087))
    ])

# %%
train_dataset = torchvision.datasets.MNIST(root = './data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.MNIST(root = './data', train=False, download=True, transform = transform)

# %%
train_dataset.data.shape
# Out:
# torch.Size([60000, 28, 28])

# %%
BATCH_SIZE = 100

train_loader = DataLoader(
    train_dataset,
    batch_size = BATCH_SIZE,
    shuffle=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size = 1000,
    shuffle=False
)

# %%
# Device Configuration
device = torch.device("cuda:0" if torch.cuda_is_available() else "cpu")

input_dim = 28 * 28
output_dim = 10
hidden_dim = 100
lr = 0.1
batch_size = BATCH_SIZE
num_epochs = 5

class FeedForwardModel(nn.Module):
  def __init__(self, input_dim, hidden_dim, output_dim):
    super(FeedForwardModel, self).__init__()
    self.fc1 = nn.Linear(input_dim, hidden_dim)
    self.sigmoid = nn.Sigmoid()
    self.fc2 = nn.Linear(hidden_dim, output_dim)

  def forward(self, x):
    out = self.fc1(x)
    out = self.sigmoid(out)
    out = self.fc2(out)

model = FeedForwardModel(input_dim, hidden_dim, output_dim)

# Loss and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4239958931.py in <cell line: 0>()
#       1 # Device Configuration
# ----> 2 device = torch.device("cuda:0" if torch.cuda_is_available() else "cpu")
#       3
#       4 input_dim = 28 * 28
#       5 output_dim = 10
#
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py in __getattr__(name)
#    2755             return importlib.import_module(f".{name}", __name__)
#    2756
# -> 2757         raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#    2758
#    2759
#
# AttributeError: module 'torch' has no attribute 'cuda_is_available'

# %%
for epoch in range(num_epochs):
  for i, (images, labels) in enumerate(train_loader):
    images = images.view(-1, input_dim).to(device) # Flattening of Images
    labels = labels.to(device)

    #forward propagation
    outputs = model(images)

    # loss calculation
    loss = criterion(outputs, labels)

    # back propagation
    optimizer.zero_grad() # clears the initial gradient
    loss.backward() # computes the gradients backwards

    optimizer.step() # update weight of model

    # calculate loss
    if (i+1 % 100) == 0:
      print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipython-input-199696443.py in <cell line: 0>()
#       1 for epoch in range(num_epochs):
#       2   for i, (images, labels) in enumerate(train_loader):
# ----> 3     images = images.view(-1, input_dim).to(device) # Flattening of Images
#       4     labels = labels.to(device)
#       5
#
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     401             )
#     402         if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 403             raise AssertionError("Torch not compiled with CUDA enabled")
#     404         if _cudart is None:
#     405             raise AssertionError(
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
60000/100
# Out:
# 600.0
